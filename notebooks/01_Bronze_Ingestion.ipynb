# %%
bronze_df = spark.table("student_success.bronze.student_performance")

bronze_df.printSchema()

# %%
bronze_df = spark.table("student_success.bronze.student_performance")

print(f"Rows: {bronze_df.count()}")
print(f"Columns: {len(bronze_df.columns)}")

display(bronze_df.limit(10))

# %%
df = spark.table("student_success.bronze.student_performance")

display(df.limit(10))

# %%
# %python
df.write \
  .format("delta") \
  .mode("overwrite") \
  .saveAsTable("student_success.bronze.student_performance")

# %%
# %python
df.printSchema()

# %%
# %python
print(df.count())
print(len(df.columns))

# %%
# %python
df = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv("/Volumes/student_success/bronze/raw_files/Student_Performance.csv")

display(df)
